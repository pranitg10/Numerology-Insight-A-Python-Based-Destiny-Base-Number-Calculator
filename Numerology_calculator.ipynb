# %%
day=int(input('Enter your day of birth: '))
if 0< day < 32:
    day=day
else:
    print('Invalid day')
    day=int(input('Enter your day of birth: '))
    
month=int(input('Enter your month birth: '))
if 0< month < 13:
    month=month
else:
    print('Invalid month')
    month=int(input('Enter your month birth: '))
    
year=int(input('Enter your year of birth: ' ))
if year<=2024:
    year=year
else:
    print('Invalid year')
    year=int(input('Enter your year of birth: ' ))
    
(day, month, year)

print()

sum_y=int(str(year)[0])+int(str(year)[1])+int(str(year)[2])+int(str(year)[3])
sum_y

if 9<month:
    sum_m=int(str(month)[0])+int(str(month)[1])
else:
    sum_m=month
sum_m

if day>9:
    sum_d=int(str(day)[0])+int(str(day)[1])
else:
    sum_d=day
sum_d   

destiny_num=sum_d 
destiny_num

print('Your destiny number is: ', destiny_num)

print()

if destiny_num==1:
    print('Leadership, individuality, new beginnings.')
    print('This number signifies new beginnings, independence, and leadership. It represents ambition, drive, and individuality. People influenced by the number 1 are often determined, self-reliant, and innovative. They have strong leadership qualities and tend to initiate action, paving the way for others to follow.')
elif destiny_num==2:
    print('Harmony, partnership, diplomacy.')
    print('Number 2 embodies harmony, balance, and cooperation. It symbolizes partnership, diplomacy, and sensitivity to others needs. Those influenced by the number 2 are often peacemakers, adept at resolving conflicts and fostering collaboration. They value relationships and seek to create unity in their environment.')
elif destiny_num==3:
    print('Creativity, expression, joy.')
    print('This number represents creativity, self-expression, and joy. It embodies optimism, enthusiasm, and a zest for life. Individuals influenced by the number 3 are often artistic, charismatic, and sociable. They have a natural ability to inspire others and bring energy to any situation.')
elif destiny_num==4:
    print('Stability, structure, organization.')
    print('Number 4 signifies stability, structure, and practicality. It represents hard work, discipline, and organization. People influenced by the number 4 are reliable, methodical, and grounded. They excel in building solid foundations and thrive in environments where structure is essential.')
elif destiny_num==5:
    print('Freedom, versatility, adventure.')
    print('Number 5 embodies freedom, versatility, and adventure. It symbolizes adaptability, curiosity, and a willingness to embrace change. Those influenced by the number 5 are adventurous, dynamic, and resourceful. They seek excitement and new experiences, often thriving in unpredictable situations.')
elif destiny_num==6:
    print('Nurturing, responsibility, compassion.')
    print('This number represents nurturing, responsibility, and compassion. It symbolizes love, harmony, and domesticity. Individuals influenced by the number 6 are often caring, empathetic, and family-oriented. They prioritize relationships and excel in roles that require caregiving and support.')
elif destiny_num==7:
    print('Introspection, spirituality, wisdom.')
    print('Number 7 signifies introspection, spirituality, and wisdom. It represents inner-knowing, intuition, and a quest for knowledge. People influenced by the number 7 are often analytical, introspective, and deeply spiritual. They seek meaning in life and are drawn to philosophical or metaphysical pursuits.')
elif destiny_num==8:
    print('Ambition, success, abundance.')
    print('This number embodies ambition, success, and abundance. It symbolizes power, achievement, and material wealth. Those influenced by the number 8 are often driven, determined, and entrepreneurial. They possess strong leadership skills and strive for financial security and success.')
elif destiny_num==9:
    print('Completion, humanitarianism, universal love.')
    print('Number 9 signifies completion, humanitarianism, and universal love. It represents compassion, generosity, and a desire to serve humanity. Individuals influenced by the number 9 are often altruistic, idealistic, and compassionate. They are motivated by a sense of purpose and seek to make a positive impact on the world.')
    
print()

base_num=sum_d+sum_m+sum_y
if base_num>9:
    base_num=int(str(base_num)[0])+int(str(base_num)[1])
if base_num>9:
    base_num=int(str(base_num)[0])+int(str(base_num)[1])
print('Your base number is', base_num)
# Out:
# Enter your day of birth: 13
# Enter your month birth: 05
# Enter your year of birth: 1999
#
# Your destiny number is:  4
#
# Stability, structure, organization.
# Number 4 signifies stability, structure, and practicality. It represents hard work, discipline, and organization. People influenced by the number 4 are reliable, methodical, and grounded. They excel in building solid foundations and thrive in environments where structure is essential.
#
# Your base number is 1

# %%
import gradio as gr


def numerology_calculator(day, month, year):

    if not (1 <= day <= 31):
        return "Invalid day"
    if not (1 <= month <= 12):
        return "Invalid month"
    if year > 2024:
        return "Invalid year"
    

    sum_y = sum(int(digit) for digit in str(year))
    sum_m = sum(int(digit) for digit in str(month))
    sum_d = sum(int(digit) for digit in str(day))
    
    destiny_num = sum_d
    base_num = sum_d + sum_m + sum_y
    

    while base_num > 9:
        base_num = sum(int(digit) for digit in str(base_num))
    

    interpretations = {
        1: """Leadership, individuality, new beginnings.
              Number 1 signifies new beginnings, independence, and leadership. 
              It represents ambition, drive, and individuality. 
              People influenced by the number 1 are often determined, self-reliant, and innovative. 
              They have strong leadership qualities and tend to initiate action, paving the way for others to follow""",
        2: """Balance, partnership, sensitivity.
              Number 2 embodies harmony, balance, and cooperation. It symbolizes partnership, diplomacy, and sensitivity to others needs. 
              Those influenced by the number 2 are often peacemakers, adept at resolving conflicts and fostering collaboration. 
              They value relationships and seek to create unity in their environment. """,
        3: """Creativity, expression, communication.
              Number 3 represents creativity, self-expression, and joy. 
              It embodies optimism, enthusiasm, and a zest for life. 
              Individuals influenced by the number 3 are often artistic, charismatic, and sociable. 
              They have a natural ability to inspire others and bring energy to any situation. """,
        4: """Stability, structure, organization.
              Number 4 signifies stability, structure, and practicality. 
              It represents hard work, discipline, and organization. 
              People influenced by the number 4 are reliable, methodical, and grounded. 
              They excel in building solid foundations and thrive in environments where structure is essential.""",
        5: """Change, adventure, freedom.
              Number 5 embodies freedom, versatility, and adventure. 
              It symbolizes adaptability, curiosity, and a willingness to embrace change. 
              Those influenced by the number 5 are adventurous, dynamic, and resourceful. 
              They seek excitement and new experiences, often thriving in unpredictable situations. """,
        6: """Nurturing, responsibility, compassion.
              Number 6 represents nurturing, responsibility, and compassion. 
              It symbolizes love, harmony, and domesticity. 
              Individuals influenced by the number 6 are often caring, empathetic, and family-oriented. 
              They prioritize relationships and excel in roles that require caregiving and support.""",
        7: """Introspection, spirituality, wisdom.
              Number 7 signifies introspection, spirituality, and wisdom. 
              It represents inner-knowing, intuition, and a quest for knowledge. 
              People influenced by the number 7 are often analytical, introspective, and deeply spiritual. 
              They seek meaning in life and are drawn to philosophical or metaphysical pursuits.""",
        8: """Ambition, success, abundance.
              This number embodies ambition, success, and abundance. It symbolizes power, achievement, and material wealth. 
              Those influenced by the number 8 are often driven, determined, and entrepreneurial. 
              They possess strong leadership skills and strive for financial security and success.""",
        9: """Completion, humanitarianism, universal love.
              Number 9 signifies completion, humanitarianism, and universal love. 
              It represents compassion, generosity, and a desire to serve humanity. 
              Individuals influenced by the number 9 are often altruistic, idealistic, and compassionate. 
              They are motivated by a sense of purpose and seek to make a positive impact on the world."""
    }
    
    destiny_message = interpretations.get(destiny_num, "Unknown destiny number.")
    base_message = f"Your base number is {base_num}."

    return f"Your destiny number is: {destiny_num}\n{destiny_message}\n\n{base_message}"


interface = gr.Interface(
    fn=numerology_calculator,
    inputs=[
        gr.Number(label="Day of Birth", value=0, precision=0),
        gr.Number(label="Month of Birth", value=0, precision=0),
        gr.Number(label="Year of Birth", value=0, precision=0)
    ],
    outputs="text",
    title="Numerology Insight Calculator",
    description="Enter your birth date to calculate your Destiny and Base numbers with numerological interpretations."
)


interface.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7864
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7864/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
